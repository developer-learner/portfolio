# %% [markdown]
# # Assignment 1 - Yusuf Mohammed

# %%
#Exercise 1

# %%
#Defines a variable, assigns a string value, and prints it
strX = "This is a new string."
print(strX)

# %%
#Defines a variable, assigns the requested string value, and prints it
strY = "I'm a student"
print(strY)

# %%
#Defines a variable, assigns a string value that provides course feedback so far, and prints it
strZ = "I like that I am learning programming finally.\nYay! I like this course."
print(strZ)

# %%
#Exercise 2

# %%
#Defines variables, performs requested operation on them, and prints the output
a, b = 100, 9
c = a + b
print(c)
print(a//b)
print(int(a/b))
print(a%b)
print(a**b)
print(a!=b)
print(a>b)

# %%
#Exercise 3

# %%
#Defines a list with integer, float, and string elements and with a length greater than 5
List_A = [1, 1.53333, "some string", "some more string", 0, 2]

#Defines another list
List_B = [25, 9]

# Extends List_A with elements of List_B
List_A.extend(List_B)
print(List_A)
# Out:
# [1, 1.53333, 'some string', 'some more string', 0, 2, 25, 9]

# %%
#Inserting an element at second place of the list - that is at index 1
List_A.insert(1, "FE520")
print(List_A)

#Deleting a specific element of the list
List_A.remove("FE520")

#Printing the last element of the list
print(List_A[-1])

#Removing the last element of the list
del List_A[-1]

#prints the new list
print(List_A)
# Out:
# [1, 'FE520', 1.53333, 'some string', 'some more string', 0, 2, 25, 9]
# 9
# [1, 1.53333, 'some string', 'some more string', 0, 2, 25]

# %%
#Creates a new list as a slice of List_A
List_C = List_A[3:]

#Doubles the list length by appending a copy of itself
List_C.extend(List_C)
print(List_C)

#Reverses the list elements
List_C.reverse()
print(List_C)
# Out:
# ['some more string', 0, 9, 25]
# ['some more string', 0, 9, 25, 'some more string', 0, 9, 25]
# [25, 9, 0, 'some more string', 25, 9, 0, 'some more string']

# %%
#Exercise 4

# %%
# Defines a list with elements
A = [1,2,3,2,1,7]

#Defines an empty dictionary
D = {}

#Loops through the elements of list A and for each elements and its count,
#stores that as a key-value pair in the dictionary 
for i in A :
    if i in D.keys():
        D[i] += 1
    else :
        D[i] = 1
print(D)
# Out:
# {1: 2, 2: 2, 3: 1, 7: 1}

# %%
#Exercise 5

# %%
#Defines a list with elements
A = [1,2,3,4,5,6]

#defines a sum variable with value assigned as 0
sum = 0

#Loops through list A and adds each element value to sum variable
for i in A :
    sum += i

#Calculates average from the sum and length variables
total_num = sum / len(A)
print(total_num)
# Out:
# 3.5

# %%
#Exercise 6

# %%
#Defines list x and y as the given dataset of independent and dependent variable respectively
x = [[0.18], [1.0], [0.92], [0.07], [0.85], [0.99], [0.87]]

y = [[109.85], [155.72], [137.66], [76.17], [139.75], [162.6], [151.77]]

#Assumes initial values for m,c and L
m = 0 #Slope of line
c = 0 #y intercept of line
L = 0.001 #Learning rate

#calculates the length of the input x list
n = len(x)

#Performs 200 loops 
for z in range(200):
    #Defines predictive dependent variable ypred list, calculated from formula.
    ypred = []
    #Defines empty list Dm and Dc
    Dm = []
    Dc = []
    
    #Defines sum of element in Dm and Dc
    sumDm = 0
    sumDc = 0
    
    #Loops for length of the x list, calculates predicted values for y
    #Appends calculated values to Dm and Dc list
    for i in range(n) :
        ypred.append([x[i][0]*m + c])
        Dm.append(x[i][0]*(ypred[i][0]-y[i][0]))
        Dc.append(ypred[i][0]-y[i][0])
        sumDm += Dm[i]
        sumDc += Dc[i]

    #Loops and sums the values in Dm and Dc
    #for i in range(n) :
       # sumDm += Dm[i]
        #sumDc += Dc[i]
    
    #calculates average value of elements of Dm and Dc
    dm = sumDm / n
    dc = sumDc / n

    #Based on values of dm and dc, updates new values of m and c
    m = m - L*dm
    c = c - L*dc
    
    #Prints the current value of m and c
    print(m,c)
# Out:
# 0.10275335714285715 0.13336
# 0.2053499892598939 0.2665150062310204
# 0.30779013650221376 0.3994653329465625
# 0.41007403865283726 0.5322112939184545
# 0.512201935127266 0.6647532024375895
# 0.6141740649740459 0.7970913713146632
# 0.7159906668753301 0.9292261128809095
# 0.8176519791474398 1.0611577389888356
# 0.9191582397414257 1.1928865610129553
# 1.0205096862436274 1.3244128898505225
# 1.1217065558762325 1.4557370359222621
# 1.222749085497835 1.5868593091731005
# 1.3236375116039922 1.7177800190728947
# 1.4243720703277816 1.8484994746171608
# 1.524952997440356 1.9790179843278008
# 1.6253805283514984 2.109335856253829
# 1.7256548981101762 2.239453397972096
# 1.825776341405094 2.3693709165880126
# 1.9257450925652455 2.4990887187362736
# 2.025561385560465 2.6286071105815774
# 2.1252254540019786 2.757926397819348
# 2.224737531142953 2.887046885676453
# 2.324097849879044 3.0159688789119223
# 2.4233066427489462 3.1446926818176664
# 2.522364141934938 3.2732185982191893
# ...
